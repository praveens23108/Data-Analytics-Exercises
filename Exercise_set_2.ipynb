# %% [markdown]
# ## Question 1

# %% [markdown]
# **Print the head of the data**

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("loans.csv")

df.head()
# Out:
#                                 Loan ID  Loan Status  Current Loan Amount  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048   Fully Paid            445412.00
# 1  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26   Fully Paid          99999999.00
# 2  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a   Fully Paid            347666.00
# 3  89d8cb0c-e5c2-4f54-b056-48a645c543dd  Charged Off            206602.00
# 4  273581de-85d8-4332-81a5-19b04ce68666   Fully Paid            217646.00
#
#          Term  Credit Score  Annual Income Home Ownership             Purpose  \
# 0  Short Term        709.00     1167493.00  Home Mortgage   Home Improvements
# 1  Short Term        741.00     2231892.00       Own Home  Debt Consolidation
# 2   Long Term        721.00      806949.00       Own Home  Debt Consolidation
# 3  Short Term       7290.00      896857.00  Home Mortgage  Debt Consolidation
# 4  Short Term        730.00     1184194.00  Home Mortgage  Debt Consolidation
#
# ...

# %% [markdown]
# **Remove (filter out) loans that are unrealistically large**

# %%
large_loans = df[df['Current Loan Amount'] < 99999999]

large_loans
# Out:
#                                     Loan ID  Loan Status  Current Loan Amount  \
# 0      14dd8831-6af5-400b-83ec-68e61888a048   Fully Paid            445412.00
# 2      77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a   Fully Paid            347666.00
# 3      89d8cb0c-e5c2-4f54-b056-48a645c543dd  Charged Off            206602.00
# 4      273581de-85d8-4332-81a5-19b04ce68666   Fully Paid            217646.00
# 5      8af915d9-9e91-44a0-b5a2-564a45c12089   Fully Paid            548746.00
# ...                                     ...          ...                  ...
# 70313  3b2a09bb-3467-4d2f-bd8f-260fdc5760be   Fully Paid            179454.00
# 70314  38530a21-5a57-47f5-9aaa-b4475b1db345   Fully Paid            781022.00
# 70316  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0   Fully Paid            210584.00
# 70318  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7   Fully Paid            103136.00
# 70319  81ab928b-d1a5-4523-9a3c-271ebb01b4fb   Fully Paid            530332.00
#
# ...

# %% [markdown]
# **Which loan(s) have the highest Current Credit Balance?**

# %%
largest = df.nlargest(58893,'Current Credit Balance')
largest
# Out:
#                                     Loan ID  Loan Status  Current Loan Amount  \
# 12459  c194cb68-1c4d-4bba-8433-98cf4e0f357d  Charged Off            762850.00
# 34554  c4c387b5-7708-4f96-bf0a-6b23a60f196c   Fully Paid            761684.00
# 49789  007ebd31-1453-4d04-97f4-97737e01c608   Fully Paid            235312.00
# 68019  3dbc3b41-ad17-4b11-aa78-246c3afdc191   Fully Paid            773784.00
# 38748  9dfa56f4-ced5-4cce-ad91-076068c1910b   Fully Paid            760298.00
# ...                                     ...          ...                  ...
# 32168  4d66dd9a-4495-43c2-9090-df85fc493245   Fully Paid            760848.00
# 45198  b2954422-a9ff-4479-9ba7-386e4e17468e   Fully Paid            143726.00
# 68393  62071613-1c9d-4177-8444-f12c31e456ec   Fully Paid            132044.00
# 24103  ee6331d0-a9bc-458c-9cfd-30efc0c96091   Fully Paid          99999999.00
# 61587  c0114165-9986-4c31-842b-c1d4adff9752   Fully Paid          99999999.00
#
# ...

# %% [markdown]
# **Which loan(s) have the smallest Annual Income?**

# %%
smallest = df.nsmallest(58893,'Annual Income')
smallest
# Out:
#                                     Loan ID  Loan Status  Current Loan Amount  \
# 48729  fdda52f3-bbfa-45da-80b5-2bd9b68638ed  Charged Off             30448.00
# 38169  9ed28b3a-c3a9-4ae4-93e6-3de7ff42f64e   Fully Paid             61490.00
# 49094  8f65d638-5789-46af-99f2-72c4d03c9321   Fully Paid          99999999.00
# 70054  a8539cc1-63d7-4e2e-bddb-4dd1a074182c   Fully Paid          99999999.00
# 7624   241e16a3-c198-4d8e-8dad-c927fd7c7d24   Fully Paid             34342.00
# ...                                     ...          ...                  ...
# 14247  7af640a0-ecda-4802-a1ab-3aa34bb9b83d   Fully Paid            222574.00
# 48079  9a626b8d-a754-436f-9052-64147c898aeb   Fully Paid            133540.00
# 68835  0197dd94-b587-440d-98c3-e3e89e2e0878   Fully Paid            333872.00
# 31520  39b13633-be67-464c-9fc8-68156701d2e3  Charged Off            340428.00
# 43355  a0803705-a82b-452a-bb3e-8a95658fcc92  Charged Off            717398.00
#
# ...

# %% [markdown]
# **Use describe(), and answer the following questions**

# %%
pd.set_option ('display.float_format','{:.2f}'.format)

describe = df['Current Loan Amount'].describe()
describe
# Out:
# count      70321.00
# mean    16512589.51
# std     36777479.40
# min        15422.00
# 25%       191268.00
# 50%       327140.00
# 75%       568942.00
# max     99999999.00
# Name: Current Loan Amount, dtype: float64

# %% [markdown]
# **Create a new field into your dataset called Actual Annual Income.**

# %%
df['Actual Annual Income'] = df['Annual Income']- (12 * df['Monthly Debt'])
df
# Out:
#                                     Loan ID  Loan Status  Current Loan Amount  \
# 0      14dd8831-6af5-400b-83ec-68e61888a048   Fully Paid            445412.00
# 1      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26   Fully Paid          99999999.00
# 2      77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a   Fully Paid            347666.00
# 3      89d8cb0c-e5c2-4f54-b056-48a645c543dd  Charged Off            206602.00
# 4      273581de-85d8-4332-81a5-19b04ce68666   Fully Paid            217646.00
# ...                                     ...          ...                  ...
# 70316  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0   Fully Paid            210584.00
# 70317  06eba04f-58fc-424a-b666-ed72aa008900   Fully Paid          99999999.00
# 70318  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7   Fully Paid            103136.00
# 70319  81ab928b-d1a5-4523-9a3c-271ebb01b4fb   Fully Paid            530332.00
# 70320  c63916c6-6d46-47a9-949a-51d09af4414f   Fully Paid          99999999.00
#
# ...

# %% [markdown]
# **How many loans are "Long term"?**

# %%
long = df['Term'].value_counts()['Long Term']
long
# Out:
# np.int64(19064)

# %% [markdown]
# **What are the 3 most common loan purposes?**

# %%
common_purposes = df['Purpose'].value_counts().head(3)
common_purposes
# Out:
# Purpose
# Debt Consolidation    55505
# other                  4196
# Home Improvements      4108
# Name: count, dtype: int64

# %% [markdown]
# **Small extra task: There seems to be two versions of "other" in the data for loan purpose**

# %%
df['Purpose'] = df['Purpose'].replace("other","Other")
df['Purpose'].value_counts()
# Out:
# Purpose
# Debt Consolidation      55505
# Other                    6464
# Home Improvements        4108
# Business Loan            1063
# Buy a Car                 920
# Medical Bills             774
# Buy House                 469
# major_purchase            260
# Take a Trip               237
# small_business            200
# moving                    110
# wedding                    76
# Educational Expenses       68
# vacation                   61
# renewable_energy            6
# Name: count, dtype: int64

# %% [markdown]
# **Small extra task: study the distribution of "Number of Credit Problems" by using value_counts(). Explain your findings**

# %%
df['Number of Credit Problems'].value_counts()


# Explanation :  Most customers has no credit problems and fewer has some issues. but there least number of customers who has with a higher number of credit problems
# Out:
# Number of Credit Problems
# 0.00    60643
# 1.00     8376
# 2.00      896
# 3.00      261
# 4.00       87
# 5.00       37
# 6.00       12
# 7.00        6
# 8.00        3
# Name: count, dtype: int64

# %% [markdown]
# **How many unique Home Ownership -options there are in the dataset?**

# %%
df['Home Ownership'].nunique()
# Out:
# 3

# %% [markdown]
# ##  Other small extra tasks:

# %% [markdown]
# **How many loaners have more than 1 bankruptcy?**

# %%
bankrupt = (df['Bankruptcies'] > 1).sum()
bankrupt
# Out:
# np.int64(376)

# %% [markdown]
# **How many Short Term loans are for Home Improvements?**

# %%
short_term= df[df['Term'] == 'Short Term']

home= short_term['Purpose'].value_counts()['Home Improvements']
home
# Out:
# np.int64(2859)

# %% [markdown]
# ## Question 2

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("purchases.csv")

df
# Out:
#       Purchase Date Purchase Order Number Acquisition Type  \
# 0        08/31/2012            4500149558      Other Goods
# 1        10/18/2012            4500156192      Other Goods
# 2        10/17/2012            4500156124      Other Goods
# 3        10/24/2012              S2556056      Other Goods
# 4        11/14/2012            4500159228      Other Goods
# ...             ...                   ...              ...
# 62468    08/23/2013              S3863002      Other Goods
# 62469    08/23/2013              S3863002      Other Goods
# 62470    08/23/2013              S3863002      Other Goods
# 62471    08/23/2013              2U3H1109   Other Services
# 62472    08/23/2013            4500195481      Other Goods
#
#          Acquisition Method                                Department Name  \
# 0        Formal Competitive  Corrections and Rehabilitation, Department of
# 1      Informal Competitive  Corrections and Rehabilitation, Department of
# ...

# %% [markdown]
# **What was the total price sum of the Purchase Order Number 018H2015? (14 rows in total)**

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("purchases.csv")

sum1 = df[df['Purchase Order Number']=='018H2015']['Total Price'].sum()
sum1
# Out:
# np.float64(1245.0400000000002)

# %% [markdown]
# **What is the item name and description of the purchased item with the Purchase Order Number 3176273?**

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("purchases.csv")


item = data[data['Purchase Order Number']=='3176273'][['Item Name','Item Description']]
item
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[90], line 7
#
#       2 import pandas as pd
#
#       4 df = pd.read_csv("purchases.csv")
#
# ----> 7 item = data[data['Purchase Order Number']=='3176273'][['Item Name','Item Description']]
#
#       8 item
#
#
#
# NameError: name 'data' is not defined

# %% [markdown]
# **How many occasions (rows) of purchase data happened during the year 2013?**

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("purchases.csv")

df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])

df['Year'] = df['Purchase Date'].dt.year

occasion2013 = len(df[df['Year'] == 2013])

occasion2013

# %% [markdown]
# **What are the 5 most common Departments in the data?**

# %%
Department = df['Department Name'].value_counts().head(5)
Department
# Out:
# Department Name
# Corrections and Rehabilitation, Department of    10858
# Correctional Health Care Services                 6591
# Water Resources, Department of                    4566
# Forestry and Fire Protection, Department of       4513
# State Hospitals, Department of                    4258
# Name: count, dtype: int64

# %% [markdown]
# **Replace the $-sign in the Unit Price –column with an empty string,and convert the value to float**

# %%
df['Unit Price'] = df['Unit Price'].str.replace('$', '').astype(float)
df

# %% [markdown]
# **Smaller extra tasks**

# %%
# How many purchases in the data were IT Goods and had the total price of more than 50000 dollars?

IT = df[(df['Acquisition Type'] == 'IT Goods') & (df['Total Price'] > 50000)]
count = len(IT)
count

# %%
# How many of the purchases have anything to do with IT? 

it_purchases = df[(df['Acquisition Type'] == 'IT Goods') | 
                  (df['Acquisition Type'] == 'IT Services') |
                  (df['Acquisition Type'] == 'IT Telecommunications')]
count = len(it_purchases)
count

# %% [markdown]
# ## Question 3

# %%
import numpy as np
import pandas as pd

df= pd.read_csv("salaries_india.csv")

df
# Out:
#        Row ID                                Company Name     Rating  \
# 0       79417                                   Unacademy       Good
# 1       79419                      Appoids Tech Solutions       Good
# 2       79424             Endeavour Software Technologies       Good
# 3       79427                                       Wibmo       Good
# 4       79429                                  Bookmyshow       Good
# ...       ...                                         ...        ...
# 10782  102163  Full Time Soluções em Serviços Financeiros       Good
# 10783  102167                                 SwervePoint       Good
# 10784  102168                                      rtCamp       Good
# 10785  102173                       Blu Ocean Innovations  Excellent
# 10786  102178                              Unicon Systems       Good
#
#                     Job Title     Salary  Salaries Reported   Location  \
# ...

# %% [markdown]
# **Remove the columns "Row ID" and "Job Title"**

# %%
import numpy as np
import pandas as pd

df= pd.read_csv("salaries_india.csv")


df = df.drop(columns=['Row ID', 'Job Title'])
df
# Out:
#                                      Company Name     Rating     Salary  \
# 0                                       Unacademy       Good 2046000.00
# 1                          Appoids Tech Solutions       Good 1227600.00
# 2                 Endeavour Software Technologies       Good 1227600.00
# 3                                           Wibmo       Good 1841400.00
# 4                                      Bookmyshow       Good 1227600.00
# ...                                           ...        ...        ...
# 10782  Full Time Soluções em Serviços Financeiros       Good 2406096.00
# 10783                                 SwervePoint       Good 1227600.00
# 10784                                      rtCamp       Good 1432200.00
# 10785                       Blu Ocean Innovations  Excellent  967572.00
# 10786                              Unicon Systems       Good 1023000.00
#
#        Salaries Reported   Location Employment Status Job Roles
# ...

# %% [markdown]
# **How large are the highest salaries in this dataset?**

# %%
outliers = df['Salary'].value_counts().sort_index(ascending=False).head(10)
outliers

# AI was used to find the answer
# Out:
# Salary
# 9284422.50    1
# 8644117.50    1
# 8421043.50    1
# 8109153.00    2
# 8010090.00    4
# 8003812.50    2
# 7803378.00    1
# 7797262.50    1
# 7733880.00    5
# 7683660.00    1
# Name: count, dtype: int64

# %%
# Remove all salaries that are too high

cutoff = df['Salary'].quantile(0.99)
filtered_df = df.loc[df['Salary'] <= cutoff]
salary_count = len(filtered_df)
salary_count
# Out:
# 10688

# %% [markdown]
# **Handle "Employment Status" as a binary variable**

# %%
from sklearn.preprocessing import LabelEncoder


encoder = LabelEncoder()

df['Employment Status'] = encoder.fit_transform(df['Employment Status'])


df.head()

# %% [markdown]
# **Handle "Rating" as an ordinal variable**

# %%
rating_encoding = {'Poor': 1, 'Average': 2, 'Good': 3, 'Excellent': 4}
df['Rating_Encoded'] = df['Rating'].replace(rating_encoding)
encoded_result = df[['Rating', 'Rating_Encoded']]
encoded_result 

# used AI to find the answer. But code did not work.

# %% [markdown]
# **Handle "Job Roles" and "Location" as NOMINAL categories**

# %%
df_encoded = pd.get_dummies(df, columns=['Job Roles', 'Location'])
last_nominal = df_encoded
last_nominal
# Out:
#        Row ID                                Company Name     Rating  \
# 0       79417                                   Unacademy       Good
# 1       79419                      Appoids Tech Solutions       Good
# 2       79424             Endeavour Software Technologies       Good
# 3       79427                                       Wibmo       Good
# 4       79429                                  Bookmyshow       Good
# ...       ...                                         ...        ...
# 10782  102163  Full Time Soluções em Serviços Financeiros       Good
# 10783  102167                                 SwervePoint       Good
# 10784  102168                                      rtCamp       Good
# 10785  102173                       Blu Ocean Innovations  Excellent
# 10786  102178                              Unicon Systems       Good
#
#                     Job Title     Salary  Salaries Reported Employment Status  \
# ...

# %% [markdown]
# **Analyze the correlation matrix from the point of view of Salary**

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
corr_data = numeric_df.corr()
salary_corr_values = corr_data.loc[:, ['Salary']].sort_values('Salary', ascending=False)
salary_corr_values
# Out:
#                            Salary
# Salary                       1.00
# Job_Roles_Code               0.25
# Rating_Ordinal               0.19
# Row ID                       0.10
# Salaries Reported            0.09
# Employment_Status_Numeric   -0.08
# Location_Code               -0.27

# %% [markdown]
# **Which variables have the biggest impact on a salary?**

# %% [markdown]
# Looking at the correlation matrix, Rating_Ordinal shows the strongest relationship with salary at 0.192, while other variables like Row ID and Salaries Reported have very weak correlations below 0.1.

# %% [markdown]
# **Try also experimenting with the outlier cutoff point,does it affect the correlations if you cut more high salaries out of the data in the earlier phase?**

# %%
corr_all = df['Salary'].corr(df['Rating_Ordinal'])
df_clean = df[df['Salary'] <= 500000]
corr_clean = df_clean['Salary'].corr(df_clean['Rating_Ordinal'])

corr_comparison = pd.DataFrame({'Type': ['All Data', 'After Outlier Removal'], 'Correlation': [corr_all, corr_clean]})
corr_comparison
# Out:
#                     Type  Correlation
# 0               All Data         0.19
# 1  After Outlier Removal         0.55
